# %%
# task - models that predicts what field someone should go into
# the function that are being used is fit(), predict(), and score()
# skit-learn is the peramenters for these functions

# %%
pip install scikit-learn
# Out:
# ...
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
model = 'DecisionTreeClassifier'
model.fit()
score()
predict()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 2
#       1 model = 'DecisionTreeClassifier'
# ----> 2 model.fit()
#       3 score()
#       4 predict()
#
# AttributeError: 'str' object has no attribute 'fit'

# %% [markdown]
# # fit() train your model on example
# # predict() makes predictions
# # score() measures accuracy
