# %%
# Creating a variable which contains a password
password = "incognito"

# %%
# Checking the length of the password using the len() function.
len("incognito")
# Out:
# 9

# %%
password_length = len(password)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 password_length = len(password)
#
# TypeError: object of type 'int' has no len()

# %%
# Checking the Software  Quality Assurance of password
print(password)
print(type(password))
# Out:
# 9
# <class 'int'>

# %%
# Converting it to a string
password = str(password)
password_length =len(password)
print(password_length)
# Out:
# 1

# %%
# safely coverting password so other codes want crash
password_length = len(str(password))
print(password_length)
# Out:
# 1

# %%
password = "incognito"
password_length = len(str(password))
print(password_length)
# Out:
# 9

# %%
# Create a labeled SQA print to make sure the calculated length is actually correct and the len function is working as intended (WAI)
print(type(str(password_length)))
# Check if their password contains a # symbol. If it doesn't tell them that they need to add one!
print("Make sure you have a pound symbol")
# Out:
# <class 'str'>
# Make sure you have a pound symbol
