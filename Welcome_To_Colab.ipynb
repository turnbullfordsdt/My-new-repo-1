# %% [markdown]
# <a href="https://colab.research.google.com/github/djuanthomas22/My-new-repo/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 floor = 'tiles'
 money = "1,000"
 print(f"We need {money} for the {floor}.")
# Out:
# We need 1,000 for the tiles.

# %% [markdown]
# Floor is the variable to tiles. Money is the variable for 1,000.

# %%
Floor = 'rugs'
money = "$1500"
print(f"The_house_needs_{money}_for_the_{floor}.")
# Out:
# The_house_needs_$1500_for_the_tiles.

# %% [markdown]
# Floor is the variable for rugs and money is the varibale for $1500.

# %%
person = "DJuan"
food = "apple"
animal = "rabbit"
print(f"{person}_gave_the_{food}_to_the_{animal}.")
# Out:
# DJuan_gave_the_apple_to_the_rabbit.

# %% [markdown]
# Person is the varible for DJuan, food is the variable for apple and animal is th variable for rabbit. Also I used underscores to get used to not being able to use spaces in my strings.
